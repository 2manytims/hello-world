# %% [markdown]
# <a href="https://colab.research.google.com/github/2manytims/hello-world/blob/main/first_model_with_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
